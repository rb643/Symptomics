# %%
options(warn=-1)

# load libraries 
library(igraph)
library(bootnet)
library(qgraph)
library(Hmisc)
library(ggplot2)
library(VIM)
library(gplots)
library(mice)
library(Rmisc)
library(dplyr)

# %% [markdown]
# read, filter and split data using the most commonly used variables from the ssc data

# %%
#if we already did the analysis then just reload it
if (file.exists("card.RData")) {
    # if the file exists we don't need to re-run most analysis later anyway and can go directly to plotting
    load(file="card.RData")
} else {

    df = read.csv("./Input/card.csv")
    
    # OPTIONAL: remove the cbcl questions
    removeVar = grepl( "cbcl", names(df))
    df = df[,!removeVar]
    
    # OPTIONAL: remove the physiological measures
    df = subset(df, select=-c(bmi, height, weight, head_circumference,individual))

    #inspect completeness
    aggr_plot <- aggr(df, col=c('navyblue','red'), 
                  numbers=TRUE, sortVars=TRUE, 
                  labels=names(data), cex.axis=.3, 
                  gap=3, ylab=c("Histogram of missing data","Pattern"))

    print(paste("Total number of subjects before NA removal: ", toString(nrow(df))))
    #remove subjects with missing data
    df = df[complete.cases(df), ]
    print(paste("Total number of subjects after NA removal: ", toString(nrow(df))))

    #split genders
    df.M = subset(df, sex == 'male')
    df.F = subset(df, sex == 'female')
    df.M = subset(df.M, select=-c(sex))
    df.F = subset(df.F, select=-c(sex))
    
}

#print some numbers to the console for verification
        print(paste("Male: ", toString(nrow(df.M))))
        print(paste("Female: ", toString(nrow(df.F))))
        print(paste("Total number of variables: ", toString(length(df))))
# Out:
#  Variables sorted by number of missings:
#                       Variable        Count
#           srs_parent_cognition 0.0048453224
#       srs_parent_communication 0.0048453224
#           srs_parent_awareness 0.0037271711
#          srs_parent_mannerisms 0.0037271711
#          srs_parent_motivation 0.0037271711
#           abc_iv_hyperactivity 0.0018635855
#     abc_v_inappropriate_speech 0.0018635855
#             abc_iii_stereotypy 0.0014908684
#                abc_ii_lethargy 0.0014908684
#             abc_i_irritability 0.0014908684
#   rbs_r_vi_restricted_behavior 0.0014908684
#      rbs_r_v_sameness_behavior 0.0014908684
#        rbs_r_ii_self_injurious 0.0011181513
#   rbs_r_i_stereotyped_behavior 0.0011181513
#  rbs_r_iv_ritualistic_behavior 0.0011181513
#                       ados_css 0.0011181513
#  rbs_r_iii_compulsive_behavior 0.0007454342
#                  a1_non_echoed 0.0003727171
#             ados_communication 0.0003727171
#         ados_reciprocal_social 0.0003727171
#          vabs_ii_communication 0.0003727171
#           vabs_ii_dls_standard 0.0003727171
#           vabs_ii_soc_standard 0.0003727171
#                     ados_comms 0.0003727171
#                       ados_rrb 0.0003727171
#                    ados_affect 0.0003727171
#                     ados_total 0.0003727171
#                            sex 0.0000000000
# [1] "Total number of subjects:  2655"
# [1] "Male:  2297"
# [1] "Female:  358"
# [1] "Total number of variables:  28"
# plot without title

# %%
head(df)
# Out:
#   a1_non_echoed abc_iii_stereotypy abc_ii_lethargy abc_i_irritability
# 1 0             3                  4                9
# 2 1             0                  0                6
# 3 0             0                  4                6
# 4 0             6                  8               18
# 5 0             8                  1               15
# 6 0             5                  6                7
#   abc_iv_hyperactivity abc_v_inappropriate_speech ados_communication
# 1 24                   7                          3
# 2  8                   1                          3
# 3  1                   3                          5
# 4 26                   7                          4
# 5 23                   5                          8
# 6 27                   0                          4
#   ados_reciprocal_social rbs_r_iii_compulsive_behavior rbs_r_ii_self_injurious
# 1  7                      3                            6
# 2  7                      0                            0
# 3  8                      6                            1
# 4  5                      6                            0
# 5 10                     14                            7
# 6  8                      1                            2
#   ⋯ srs_parent_motivation vabs_ii_communication vabs_ii_dls_standard
# 1 ⋯ 16                    72                    78
# 2 ⋯  5                    82                    76
# 3 ⋯  3                    90                    74
# 4 ⋯ 11                    94                    76
# 5 ⋯ 17                    68                    66
# 6 ⋯  6                    90                    95
#   vabs_ii_soc_standard sex    ados_comms ados_css ados_rrb ados_affect
# 1 75                   male   10          6       5         6
# 2 78                   male   11          7       5         7
# 3 83                   female 14          9       3        12
# 4 61                   male   10          8       5         9
# 5 64                   male   19         10       4        15
# 6 89                   male   14          9       5        12
#   ados_total
# 1 11
# 2 12
# 3 15
# 4 14
# 5 19
# 6 17

# %% [markdown]
# plot means and confidence intervals for each variable by group

# %%
tempMean <- df %>% group_by(sex) %>% summarise_all(funs(mean))
tempSD <- df %>% group_by(sex) %>% summarise_all(funs(sd))

dfl1 <- melt(tempMean, id="sex")
dfl2 <- melt(tempSD, id="sex")

ggplot(dfl1, aes(x=variable, y=value, ymin=(dfl1$value - dfl2$value), ymax=(dfl1$value + dfl2$value), color = sex)) +
  geom_pointrange(alpha = 0.6, shape = 21) + 
  # geom_hline(yintercept=0, lty=2) +  # add a dotted line at x=1 after flip
  coord_flip() +  # flip coordinates (puts labels on y axis)
  ylab("Mean (SD)") + ggtitle('Group means and standard deviation') + 
  theme(axis.title.y=element_blank(),
        legend.position = c(0.7,0.4),
        legend.title = element_blank(),
        legend.text=element_text(size=8), 
        legend.background = element_rect(fill=alpha('white',0.8)))

pdf("./Output/Card_Descriptives.pdf",width=7,height=5)
ggplot(dfl1, aes(x=variable, y=value, ymin=(dfl1$value - dfl2$value), ymax=(dfl1$value + dfl2$value), color = sex)) +
  geom_pointrange(alpha = 0.6, shape = 21) + 
  # geom_hline(yintercept=0, lty=2) +  # add a dotted line at x=1 after flip
  coord_flip() +  # flip coordinates (puts labels on y axis)
  ylab("Mean (SD)") + ggtitle('Group means and standard deviation') + 
  theme(axis.title.y=element_blank(),
        legend.position = c(0.7,0.4),
        legend.title = element_blank(),
        legend.text=element_text(size=8), 
        legend.background = element_rect(fill=alpha('white',0.8)))
dev.off()
# Out:
# pdf
#   2
# plot without title

# %% [markdown]
# estimate the networks

# %%
    df.M.Network <- estimateNetwork(df.M, default = "EBICglasso")
    df.F.Network <- estimateNetwork(df.F, default = "EBICglasso")
# Out:
# Estimating Network. Using package::function:
#   - qgraph::EBICglasso for EBIC model selection
#     - using glasso::glasso
#   - qgraph::cor_auto for correlation computation
#     - using lavaan::lavCor
# Variables detected as ordinal: a1_non_echoed; ados_css
# Estimating Network. Using package::function:
#   - qgraph::EBICglasso for EBIC model selection
#     - using glasso::glasso
#   - qgraph::cor_auto for correlation computation
#     - using lavaan::lavCor
# Variables detected as ordinal: a1_non_echoed; ados_css

# %%
# network plots
# graph in same layout
Layout <- averageLayout(df.M.Network,df.F.Network)
layout(t(1:2))

Labels <- LETTERS[1:length(df.M.Network$labels)]
Names <- df.M.Network$labels


qgraph(df.M.Network$graph, layout = Layout, labels = Labels, 
     title = 'Male', nodeNames = Names, legend.cex = 0.3)
qgraph(df.F.Network$graph, layout = Layout, labels = Labels, 
     title = 'Female', nodeNames = Names, legend.cex = 0.3)

pdf("./Output/Card_Networks.pdf",width=7,height=5)
qgraph(df.M.Network$graph, layout = Layout, labels = Labels, 
     title = 'Male', nodeNames = Names, legend.cex = 0.3)
qgraph(df.F.Network$graph, layout = Layout, labels = Labels, 
     title = 'Female', nodeNames = Names, legend.cex = 0.3)
dev.off()
# Out:
# pdf
#   2
# plot without title

# %%
# centrality plots comparing groups
centralityPlot(GGM = list(male = df.M.Network, female = df.F.Network))

pdf("./Output/Card_Centrality.pdf",width=7,height=5)
    centralityPlot(GGM = list(male = df.M.Network, female = df.F.Network))
dev.off()
# Out:
# Note: z-scores are shown on x-axis rather than raw centrality indices.
# Note: z-scores are shown on x-axis rather than raw centrality indices.
# pdf
#   2
# plot without title

# %% [markdown]
# bootstrap the network edges - THIS WILL TAKE QUITE LONG!!

# %%
if (exists("df.M.boot1")){
    print("No need to re-bootstrap, already done!")
} else {
    df.M.boot1 <- bootnet(df.M.Network, nBoots = 1000,  nCores = 6)
    df.F.boot1 <- bootnet(df.F.Network, nBoots = 1000,  nCores = 6)
}
# Out:
# [1] "No need to re-bootstrap, already done!"

# %%
#plot the bootstrapped confidence intervals
plot(df.M.boot1, labels = FALSE, order = "sample", title = "Male")
plot(df.F.boot1, labels = FALSE, order = "sample", title = "Female")

pdf("./Output/Card_BootstrappedCI.pdf",width=7,height=5)
    plot(df.M.boot1, labels = FALSE, order = "sample", title = "Male")
    plot(df.F.boot1, labels = FALSE, order = "sample", title = "Female")
dev.off()
# Out:
# plot without title
# pdf
#   2
# plot without title

# %%
#plot boostrapped significant edge differences
plot(df.M.boot1, "edge", plot = "difference", onlyNonZero = TRUE,
     order = "sample", alpha = 0.001, title = "Male")
plot(df.F.boot1, "edge", plot = "difference", onlyNonZero = TRUE,
     order = "sample", alpha = 0.001, title = "Female")

pdf("./Output/Card_BootstrappedEdgeDiff.pdf",width=7,height=5)
    plot(df.M.boot1, "edge", plot = "difference", onlyNonZero = TRUE,
     order = "sample", alpha = 0.001, title = "Male")
    plot(df.F.boot1, "edge", plot = "difference", onlyNonZero = TRUE,
     order = "sample", alpha = 0.001, title = "Female")
dev.off()
# Out:
# Expected significance level given number of bootstrap samples is approximately: 0.002
# Expected significance level given number of bootstrap samples is approximately: 0.0019
# plot without title
# Expected significance level given number of bootstrap samples is approximately: 0.002
# Expected significance level given number of bootstrap samples is approximately: 0.002
# pdf
#   2
# plot without title

# %%
#plot boostrapped significant nodal strength differences
    plot(df.M.boot1, "strength", alpha = 0.001,title = "Male")
    plot(df.F.boot1, "strength", alpha = 0.001,title = "Female")

pdf("./Output/Card_StrengthDiff.pdf",width=7,height=5)
    plot(df.M.boot1, "strength", alpha = 0.001,title = "Male")
    plot(df.F.boot1, "strength", alpha = 0.001,title = "Female")
dev.off()
# Out:
# Expected significance level given number of bootstrap samples is approximately: 0.002
# Expected significance level given number of bootstrap samples is approximately: 0.002
# plot without title
# Expected significance level given number of bootstrap samples is approximately: 0.0021
# Expected significance level given number of bootstrap samples is approximately: 0.002
# pdf
#   2
# plot without title

# %%
# save intermediate steps for later
save.image(file="card.RData")

# %% [markdown]
# bootstrap the networks centrality measures - this might take a while

# %%
if (exists("df.M.boot2")){
    print("No need to re-bootstrap, already done!")
} else {
    df.M.boot2 <- bootnet(df.M.Network, type = "case", nBoots = 1000,  nCores = 6)
    df.F.boot2 <- bootnet(df.F.Network, type = "case", nBoots = 1000,  nCores = 6)
}
# Out:
# Estimating sample network...
# Estimating Network. Using package::function:
#   - qgraph::EBICglasso for EBIC model selection
#     - using glasso::glasso
#   - qgraph::cor_auto for correlation computation
#     - using lavaan::lavCor
# Variables detected as ordinal: a1_non_echoed
# Bootstrapping...
# Computing statistics...
# Estimating sample network...
# Estimating Network. Using package::function:
#   - qgraph::EBICglasso for EBIC model selection
#     - using glasso::glasso
#   - qgraph::cor_auto for correlation computation
#     - using lavaan::lavCor
# Variables detected as ordinal: a1_non_echoed
# Bootstrapping...
# Computing statistics...

# %%
#plot the bootstrapped centrality indices
    plot(df.M.boot2, title = "Male")
    plot(df.F.boot2, title = "Female")

pdf("./Output/CentralityBoot.pdf",width=7,height=5)
    plot(df.M.boot2, title = "Male")
    plot(df.F.boot2, title = "Female")
dev.off()
# Out:
# plot without title
# pdf
#   2
# plot without title

# %% [markdown]
# check the stability of all centrality measures

# %%
corStability(df.M.boot2)
corStability(df.F.boot2)
# Out:
# === Correlation Stability Analysis ===
#
# Sampling levels tested:
#    nPerson Drop%   n
# 1      592  75.0 108
# 2      776  67.2  86
# 3      960  59.4  81
# 4     1144  51.6 110
# 5     1328  43.9 104
# 6     1512  36.1  98
# 7     1696  28.3 109
# 8     1880  20.5  83
# 9     2064  12.8 116
# 10    2248   5.0 105
#
# Maximum drop proportions to retain correlation of 0.7 in at least 95% of the samples:
#
# betweenness: 0.672
#   - For more accuracy, run bootnet(..., caseMin = 0.594, caseMax = 0.75)
#
# closeness: 0.672
#   - For more accuracy, run bootnet(..., caseMin = 0.594, caseMax = 0.75)
#
# strength: 0.75
#   - For more accuracy, run bootnet(..., caseMin = 0.672, caseMax = 1)
#
# Accuracy can also be increased by increasing both 'nBoots' and 'caseN'.=== Correlation Stability Analysis ===
#
# Sampling levels tested:
#    nPerson Drop%   n
# 1       92  74.9 102
# 2      120  67.3  87
# 3      149  59.4  96
# 4      177  51.8  85
# 5      206  43.9 136
# 6      234  36.2 104
# 7      263  28.3  92
# 8      292  20.4  90
# 9      320  12.8  97
# 10     349   4.9 111
#
# Maximum drop proportions to retain correlation of 0.7 in at least 95% of the samples:
#
# betweenness: 0.204
#   - For more accuracy, run bootnet(..., caseMin = 0.128, caseMax = 0.283)
#
# closeness: 0.439
#   - For more accuracy, run bootnet(..., caseMin = 0.362, caseMax = 0.518)
#
# strength: 0.749
#   - For more accuracy, run bootnet(..., caseMin = 0.673, caseMax = 1)
#
# Accuracy can also be increased by increasing both 'nBoots' and 'caseN'.

# %%
# save intermediate steps for later
save.image(file="card.RData")
